# %%
import re
import jieba
from wordcloud import WordCloud
from PIL import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = ["Microsoft YaHei"]

# %%
tempfile = pd.read_csv("sinaContent.csv")

# %%
tempfile
# Out:
#              名字                                 url  \
# 0          腾讯视频        https://weibo.com/ilovevideo
# 1          腾讯体育       https://weibo.com/tengxuntiyu
# 2        腾讯微信团队        https://weibo.com/weixinteam
# 3       腾讯视频VIP  https://weibo.com/hollywoodtheatre
# 4          腾讯综艺     https://weibo.com/remendezongyi
# ..          ...                                 ...
# 166  腾讯新闻我的时代和我      https://weibo.com/u/6505340726
# 167       饭局的诱惑      https://weibo.com/u/5934477397
# 168    极品飞车OL官博      https://weibo.com/u/5896258942
# 169       腾讯漫动画      https://weibo.com/u/6863132053
# 170      腾讯视频直播      https://weibo.com/u/5792807626
#
#                                                    内容0               时间0  \
# 0    浙江卫视跨年阵容官宣 阵容海报第三波 @陈立农 @范丞丞Adam0616 @孟美岐 @鞠婧祎...  2020-12-28 19:16
# 1    哈登虽然备受争议 但今对阵开拓者的比赛 火箭少了7名球员 大胡子全场疯狂砍下44分17助攻 ...  2020-12-27 19:46
# 2    微信表情更新了 微信上线裂开表情 打开下面6张灵魂小表情 猜猜分别代表什么意思 标准答案就在...  2020-11-18 18:17
# 3    浙江卫视跨年 宣传片首发 星光熠熠 值得期待 2020年12月31日19 30 @腾讯视频 ...  2020-12-28 19:41
# 4    浙江卫视跨年 宣传片首发 星光熠熠 值得期待 O2020年12月31日19 30 @腾讯视频...  2020-12-28 19:36
# ..                                                 ...               ...
# 166  我的时代和我 公司最忙碌的时间里 蒋友柏和同事居然直接在办公室操练了起来 扫码解锁蒋友柏的高效秘籍  2018-08-19 16:01
# 167  置顶 饭局的诱惑 收官放大招 五个 爱的故事 离奇荒诞 @胡彦斌 第一次见她父母 我是一个人...  2017-09-27 20:00
# 168  置顶 Born to Race 延续了OneRepublic一贯的正能量曲风 以 竞速 为主...  2018-05-05 12:31
# 169                      化龙记广播剧超话 化龙记广播剧 师尊的叫醒服务 专业 靠谱  2020-09-30 16:34
# 170  刘些宁超话 刘些宁1023生日快乐 是表现力十足的画报小宁 是镜头感爆棚的舞台强者 见不到可...  2020-10-23 10:49
#
#          转发0      评论0       点赞0  \
# 0    65007.0   3272.0  254278.0
# 1       77.0    217.0   11666.0
# 2     8015.0  57757.0  312805.0
# 3      492.0    672.0   58924.0
# 4      616.0    939.0   68964.0
# ..       ...      ...       ...
# 166      2.0     10.0      34.0
# 167    924.0    873.0     248.0
# 168     19.0    106.0      56.0
# 169      0.0      0.0       0.0
# 170      0.0      2.0       4.0
#
#                                                    内容1               时间1  \
# 0    浙江卫视跨年 宣传片首发 星光熠熠 值得期待 2020年12月31日19 30 @腾讯视频 ...  2020-12-28 19:33
# 1    据腾讯体育记者独家了解 瑞士联邦最高法院已经撤销了国际体育仲裁法院今年2月针对孙杨的禁赛8年...  2020-12-24 07:14
# 2                                     哇哥 举起你的右手 就能马上拥有  2020-11-19 07:57
# 3    北京卫视跨年 北京跨年阵容 热血燃冰 为冬奥助力 和@Mr_凡先生 一起关注北京2022年冬...  2020-12-28 10:41
# 4    江苏卫视跨年全阵容 亚洲顶秀 点亮鲸喜时刻 群星聚力 闪耀跨年之夜 江苏卫视跨年 蓄势待发 ...  2020-12-28 09:53
# ..                                                 ...               ...
# 166  我的人生過程中 選擇了靠意志力克服一切 被告誡過意志力策略缺乏經濟性 代價太大 但這就是我 ...  2018-08-14 21:38
# 167                                          阿娇注册结婚 恭喜  2018-12-18 15:00
# 168  共和时代OneRepublic新歌 Born To Race 生而竞速 MV中国首发上线 M...               NaN
# 169  化龙记广播剧超话 化龙记超话 @腾讯动漫 出品 @霸总光线君 @吉戾 原作 @猫耳方糖工作室...               NaN
# 170  sis夏日巡音之旅 O今天17 00@sis_NoNo洪一诺 @sis_Pam徐嘉琳 @si...  2020-10-20 11:09
#
#         转发1  ...                                                内容8  \
# 0    3950.0  ...  浙江卫视跨年阵容官宣 阵容海报第一波 跑男家族来啦 2020年12月31日19 30 @腾讯...
# 1     236.0  ...  独家揭秘 孙杨禁赛8年裁决为何被撤销 孙杨聘用王牌律师团队 前后两次提出上诉 听证会程序涉嫌...
# 2     189.0  ...  微信上线青少年模式 iOS 用户更新到 7 0 17 最新版本 前往 我 设置 可开启 功能...
# 3    3797.0  ...  北京卫视跨年 北京跨年阵容 圆梦冰雪 为冬奥助力 和@UNIQ 王一博 一起关注北京2022...
# 4     780.0  ...  浙江卫视跨年阵容官宣 阵容海报第二波 @关晓彤 @张若昀 @王凯kkw @宋轶xiaoyiy...
# ..      ...  ...                                                ...
# 166   507.0  ...  @蒋友柏 忆儿时初遇大陆人备受冲击 只差没拿枪互指 蒋友柏在接受@陈晓楠 采访时回忆11岁时...
# 167     3.0  ...                         新年快乐 新的一年我们都是饭局上的小霸王 饭局的诱惑
# 168     2.0  ...  极品飞车OL两周年快到啦 周年狂欢预先集结 回归享福利 邀请领好礼 含丰厚SP 年代车礼包 ...
# 169     0.0  ...                                         配了个百花妹妹 嫁了
# 170     0.0  ...                                                NaN
#
#                   时间8     转发8    评论8      点赞8  \
# 0    2020-12-28 16:14   448.0  502.0  25222.0
# 1    2020-12-24 07:16    34.0   50.0    305.0
# 2    2020-12-18 19:33    35.0  267.0    171.0
# 3    2020-12-28 10:39  1222.0  631.0   4452.0
# 4    2020-12-28 17:01   133.0  357.0  11562.0
# ..                ...     ...    ...      ...
# 166               NaN     4.0    2.0     15.0
# 167               NaN     1.0    1.0      8.0
# 168  2019-11-26 19:13     1.0    3.0      7.0
# 169               NaN     0.0    0.0      3.0
# 170               NaN     NaN    NaN      NaN
#
#                                                    内容9               时间9  \
# 0    令人心动的offer超话BB机 IC卡 魂斗罗 贪吃蛇 冷门知识点一秒就能get到 现场起哄...  2020-12-28 17:45
# 1    据名记Shams报道 火箭球员沃尔 考辛斯 戈登等将面临7天隔离 由于一名隔离中的火箭成员的...  2020-12-25 11:21
# 2    微信支持个人定制红包封面 牌面拉满 从今天开始 满足条件的个人创作者也能定制红包封面啦 定制...               NaN
# 3    加载矢志奋斗的动力 闪耀无限幸福的光芒 距离 江苏卫视跨年 播出还有3天 2020年12月3...  2020-12-28 09:58
# 4    北京卫视跨年 北京跨年阵容 冰雪狂欢 为冬奥助力 和@李现ing 一起关注北京2022年冬奥...  2020-12-28 10:47
# ..                                                 ...               ...
# 166  蒋家第四代 蒋友柏 一个姓氏 两个故乡 家族的烙印 让@蒋友柏 年少时便饱尝人情冷暖 他曾有...               NaN
# 167                  你是谁不重要 重要的是你变成谁 来@饭局狼人杀 为你的身份好好说话  2018-07-11 11:43
# 168          最撩人的餐厅 @食物语手游 今天发车啦 带你寻味千古美食之旅 下载链接 O网页链接               NaN
# 169  化龙记广播剧超话 化龙记超话 敖融 好花堪折直须折 莫待无花空折枝 穷天 大胆淫贼 竟敢夜闯...                 赞
# 170                                                NaN               NaN
#
#         转发9     评论9      点赞9
# 0     172.0   230.0  14818.0
# 1     123.0    17.0     62.0
# 2      10.0   366.0     76.0
# 3     145.0   202.0   5641.0
# 4    2133.0  1601.0   8308.0
# ..      ...     ...      ...
# 166     0.0     0.0     29.0
# 167     7.0    22.0     23.0
# 168     1.0     4.0      8.0
# 169     0.0     0.0      1.0
# 170     NaN     NaN      NaN
#
# [171 rows x 52 columns]

# %%
data = []
for index,row in tempfile.iterrows():
    for i in range(10):
        time = row["时间"+str(i)]
        if pd.isnull(time): continue
        if not time[-5:-3]: continue
        time = int(time[-5:-3])
        reweibo = row["转发"+str(i)]
        comment = row["评论"+str(i)]
        thumb = row["点赞"+str(i)]
        if reweibo <1 or comment < 1 or thumb < 1: continue
        data.append([time,reweibo,comment,thumb])
data = pd.DataFrame(data,columns = ["时间","转发","评论","点赞"])

# %%
data
# Out:
#      时间       转发      评论        点赞
# 0    19  65007.0  3272.0  254278.0
# 1    19   3950.0  2069.0  286257.0
# 2    12   1829.0  1079.0   68349.0
# 3    21   2292.0  1612.0   53330.0
# 4    12   1058.0   568.0   35983.0
# ..   ..      ...     ...       ...
# 883  11      7.0    22.0      23.0
# 884  12     19.0   106.0      56.0
# 885   0      1.0     2.0       9.0
# 886  10      1.0     2.0       8.0
# 887  19      1.0     3.0       7.0
#
# [888 rows x 4 columns]

# %%
sns.heatmap(data.corr())

# %%
fig,axes = plt.subplots(1,1,figsize=(15,8))
axes_reweibo = axes
axes_comment = axes.twinx()
axes_thumb = axes.twinx()
axes_thumb.spines["right"].set_position(("axes",1.1))

L1 = axes_reweibo.scatter(data["时间"].to_numpy(), data["转发"].to_numpy(),label = "转发",color="#F25F5C",alpha = 0.8,s=120)
L2 = axes_comment.scatter(data["时间"].to_numpy(), data["评论"].to_numpy(),label = "评论",color="#247BA0",alpha = 0.8,s=120)
L3 = axes_thumb.scatter(data["时间"].to_numpy(), data["点赞"].to_numpy(),label = "点赞",color="#FFE066",alpha = 0.8,s=120)
axes_reweibo.set_ylabel("转发")
axes_comment.set_ylabel("评论")
axes_thumb.set_ylabel("点赞")
plt.xticks(np.arange(0,25,1.0))
plt.xlabel("时间")
plt.legend([L1,L2,L3],[l.get_label()for l in [L1,L2,L3]],loc="best")
plt.show()

# %% [markdown]
# # 词频分析

# %%
def word_cleaning(content):
    content = re.sub(r"@[\u4e00-\u9fff0-9a-zA-Z_]*\s", "", content)
    content = re.sub(r"[^\u4e00-\u9fff]", "", content)
    
    return content

# %%
t = word_cleaning(tempfile["内容0"][10])

# %%
t
# Out:
# '首掌来了拜托了冰箱第六季第七期第八期小白和井宝的有趣故事快来复习看来很多人没看过那期节目你们宣传差点意思啊'

# %%
stopwords = [line.strip() for line in open("stopwords-zh.txt", encoding="UTF-8").readlines()]

# %%
" ".join(list(filter(lambda x : x not in stopwords, jieba.lcut(t))))
# Out:
# '首掌 拜托 冰箱 第六 季 第七期 第八期 小白 井宝 有趣 故事 快 复习 看来 很多 没 看过 期 节目 宣传 差点 意思'

# %%
mask = imageio.imread("nz1.jpg")

# %%
wc = WordCloud(font_path=r"C:\Windows\Fonts\msyh.ttc", mask=mask).generate(" ".join(list(filter(lambda x : x not in stopwords, jieba.lcut(t)))))

# %%
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
def make_wordCloud(tempfile):
    stopwords = [line.strip() for line in open("stopwords-zh.txt", encoding="UTF-8").readlines()]
    new = ""
    for index,row in tempfile.iterrows():
        for i in range(10):
            content = row["内容"+str(i)]
            if pd.isnull(content): continue
            new += word_cleaning(content)
    new = " ".join(list(filter(lambda x : x not in stopwords, jieba.lcut(new))))
    w_frequency = {}
    for word in new.split(" "):
        if word in w_frequency.keys():
            w_frequency[word]+=1
        else:
            w_frequency[word]= 1
    mask = Image.open("qq2.png")
    mask = ~np.array(mask)
    wc = WordCloud(
        font_path=r"C:\Windows\Fonts\msyh.ttc",
        mask=mask,
        background_color = "white",
        max_font_size=80,
        max_words=2000
    ).generate_from_frequencies(w_frequency)
    return wc,w_frequency

# %%
wc , w_frequency = make_wordCloud(tempfile)

# %%
plt.figure(figsize=(30,30))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
w_frequency
# Out:
# {'浙江': 29,
#  '卫视': 51,
#  '跨年': 63,
#  '阵容': 60,
#  '官宣': 22,
#  '海报': 33,
#  '第三': 6,
#  '波来': 9,
#  '年月日': 45,
#  '全程': 40,
#  '直播': 146,
#  '小鹅': 16,
#  '陪': 26,
#  '团圆': 10,
#  '宣传片': 6,
#  '首发': 24,
#  '星光': 89,
#  '熠熠': 6,
#  '值得': 14,
#  '期待': 74,
#  '张艺兴': 5,
#  '蔡': 4,
#  '徐坤': 4,
#  '全': 31,
#  '众星': 2,
#  '云集': 2,
#  '咖齐': 2,
#  '聚': 3,
#  '舞台': 56,
#  '东方': 17,
#  '梦圆': 4,
#  '同心': 4,
#  '跨越': 8,
#  '第一': 20,
#  '弹来': 7,
#  '哈哈哈': 5,
#  '最新': 20,
#  '预告': 27,
#  '电': 11,
#  '竞比': 1,
#  '完': 9,
#  '结束': 19,
#  '可能': 24,
#  '忠橙杯': 1,
#  '篮球赛': 1,
#  '马上': 21,
#  '担任': 7,
#  '教练': 2,
#  '布置': 1,
#  '战术': 1,
#  '团队': 17,
#  '默契': 4,
#  '配合': 4,
#  '迅速': 7,
#  '拿分': 1,
#  '王晨艺': 1,
#  '加速': 17,
#  '奔跑': 2,
#  '不慎': 1,
#  '摔倒': 1,
#  '周震南': 11,
#  '最后': 29,
#  '球': 5,
#  '终结': 1,
#  '比赛': 25,
#  '周五': 10,
#  '抢先': 14,
#  '看晚': 1,
#  '转免': 1,
#  '鹅': 103,
#  '正片': 17,
#  '里': 75,
#  '告诉': 25,
#  '展开': 523,
#  '全文': 513,
#  '第五': 14,
#  '第二': 13,
#  '第一波': 2,
#  '跑': 22,
#  '男': 10,
#  '家族': 11,
#  '令人': 36,
#  '心动': 99,
#  '超': 19,
#  '话机': 2,
#  '卡': 33,
#  '魂斗罗': 5,
#  '贪吃蛇': 2,
#  '冷门': 2,
#  '知识点': 5,
#  '一秒': 6,
#  '现场': 76,
#  '起哄': 5,
#  '梗': 6,
#  '瞬间': 31,
#  '确认': 7,
#  '眼神': 8,
#  '同龄人': 2,
#  '花絮': 24,
#  '冷': 5,
#  '知识': 11,
#  '持续': 15,
#  '输出': 4,
#  '范丞丞周': 2,
#  '深': 3,
#  '同龄': 2,
#  '哈登': 7,
#  '备受': 5,
#  '争议': 2,
#  '对阵': 4,
#  '开拓者': 1,
#  '火箭': 13,
#  '少': 4,
#  '名': 26,
#  '球员': 5,
#  '大胡子': 1,
#  '全场': 17,
#  '疯狂': 4,
#  '砍': 5,
#  '下分': 2,
#  '助攻': 7,
#  '问题': 24,
#  '要论': 1,
#  '单核': 1,
#  '带队': 3,
#  '能力': 12,
#  '詹姆斯': 6,
#  '杜兰特': 1,
#  '觉得': 20,
#  '最强': 13,
#  '腾讯': 582,
#  '体育': 29,
#  '微博': 294,
#  '投票': 62,
#  '记者': 5,
#  '独家': 32,
#  '了解': 31,
#  '瑞士': 4,
#  '联邦最高法院': 2,
#  '已经': 54,
#  '撤销': 6,
#  '国际': 6,
#  '仲裁': 1,
#  '法院': 1,
#  '今年': 32,
#  '孙杨': 9,
#  '禁赛': 3,
#  '裁决': 5,
#  '最高法院': 2,
#  '涉及': 5,
#  '详情': 51,
#  '文': 2,
#  '应虹霞': 2,
#  '勇士': 12,
#  '超话': 221,
#  '连续': 9,
#  '两场': 3,
#  '惨败': 2,
#  '对手': 3,
#  '东部': 1,
#  '冠军': 31,
#  '最大': 12,
#  '热门': 12,
#  '篮网': 2,
#  '雄鹿': 2,
#  '展现出': 3,
#  '差距': 1,
#  '全方位': 4,
#  '赛季': 9,
#  '进': 3,
#  '季后赛': 4,
#  '湖人': 8,
#  '圣诞': 46,
#  '大战': 19,
#  '独行侠': 5,
#  '明确': 3,
#  '表示': 29,
#  '不会': 11,
#  '脚踝': 1,
#  '扭伤': 1,
#  '缺阵': 3,
#  '紫金': 3,
#  '军团': 3,
#  '不能': 24,
#  '拿到': 8,
#  '新': 88,
#  '首胜': 1,
#  '浓眉': 3,
#  '狂胜': 1,
#  '森林狼': 1,
#  '篮板': 6,
#  '库兹马分': 1,
#  '施罗德': 1,
#  '分小加分': 1,
#  '哈雷尔分': 1,
#  '今天': 85,
#  '记': 6,
#  '头等功': 1,
#  '年终': 5,
#  '取胜': 1,
#  '队': 7,
#  '热火': 1,
#  '快船': 6,
#  '总冠军': 8,
#  '很大': 4,
#  '从中': 2,
#  '产生': 11,
#  '看好': 2,
#  '夺冠': 11,
#  '纽约时报': 1,
#  '消息': 8,
#  '代理律师': 1,
#  '提供': 14,
#  '相关': 9,
#  '证据': 1,
#  '证明': 3,
#  '此前': 2,
#  '颁布': 1,
#  '禁令': 1,
#  '主席团': 1,
#  '成员': 7,
#  '发表': 5,
#  '涉嫌': 2,
#  '种族歧视': 1,
#  '言论': 2,
#  '此案': 1,
#  '重审': 1,
#  '之前': 12,
#  '继续': 36,
#  '游泳': 3,
#  '生涯': 2,
#  '常规赛': 2,
#  '第轮': 3,
#  '首钢': 2,
#  '本赛季': 5,
#  '首次': 13,
#  '遭遇': 6,
#  '辽宁': 6,
#  '两队': 3,
#  '禁区': 1,
#  '核心': 2,
#  '汉密尔顿': 3,
#  '韩德君': 2,
#  '因伤': 1,
#  '缺席': 1,
#  '辽宁队': 3,
#  '首节': 1,
#  '落后': 2,
#  '情况': 11,
#  '二三两': 1,
#  '节均': 1,
#  '单节': 1,
#  '净胜': 1,
#  '扭转局势': 1,
#  '末节': 1,
#  '拉开': 3,
#  '优势': 3,
#  '奠定': 1,
#  '胜局': 1,
#  '最终': 20,
#  '击败': 1,
#  '北京队': 2,
#  '取得': 11,
#  '连胜': 7,
#  '胜负': 4,
#  '力压': 1,
#  '广东': 10,
#  '保住': 1,
#  '榜首': 1,
#  '连败': 2,
#  '揭秘': 7,
#  '聘用': 1,
#  '王牌': 2,
#  '律师': 5,
#  '两次': 3,
#  '提出': 1,
#  '上诉': 1,
#  '听证会': 1,
#  '程序': 11,
#  '违规': 3,
#  '名记': 1,
#  '报道': 3,
#  '沃尔考': 1,
#  '辛斯戈': 1,
#  '登': 1,
#  '面临': 4,
#  '天': 28,
#  '隔离': 2,
#  '一名': 11,
#  '检测': 14,
#  '阳性': 1,
#  '联盟': 42,
#  '正在': 38,
#  '执行': 4,
#  '额外': 2,
#  '追踪': 1,
#  '包括': 11,
#  '后卫': 2,
#  '戈登': 1,
#  '微信': 69,
#  '表情': 24,
#  '更新': 35,
#  '上线': 106,
#  '裂开': 1,
#  '打开': 16,
#  '下面': 8,
#  '张': 11,
#  '灵魂': 14,
#  '猜猜': 3,
#  '代表': 13,
#  '意思': 15,
#  '标准答案': 1,
#  '微信里': 2,
#  '黄脸': 1,
#  '哇哥': 1,
#  '举起': 1,
#  '右手': 1,
#  '拥有': 12,
#  '原来': 15,
#  '阿哥': 1,
#  '為': 1,
#  '什麼': 1,
#  '還是': 1,
#  '沒有': 1,
#  '发送': 4,
#  '原': 6,
#  '视频': 343,
#  '压缩': 1,
#  '方法': 1,
#  '简单': 5,
#  '快': 96,
#  '找': 16,
#  '这位': 8,
#  '文件': 6,
#  '快递': 6,
#  '员': 1,
#  '不回': 1,
#  '理由': 5,
#  '康康': 9,
#  '哪种': 4,
#  '行为学': 2,
#  '普及': 1,
#  '每个': 21,
#  '号': 32,
#  '情人节': 6,
#  '区别': 1,
#  '名字': 10,
#  '不同': 28,
#  '知道': 45,
#  '拥抱': 4,
#  '怀抱': 3,
#  '备注': 3,
#  '单身': 19,
#  '汪': 2,
#  '这题': 1,
#  '不用': 9,
#  '答': 7,
#  '收到': 16,
#  '语音': 5,
#  '条': 3,
#  '反应': 10,
#  '四大': 7,
#  '强迫症': 3,
#  '中招': 1,
#  '几个': 4,
#  '快来': 14,
#  '分享': 51,
#  '一下': 22,
#  '使用': 28,
#  '青少年': 6,
#  '模式': 9,
#  '用户': 55,
#  '版本': 22,
#  '前往': 9,
#  '设置': 7,
#  '开启': 60,
#  '功能': 25,
#  '部分': 4,
#  '保护': 16,
#  '限制': 9,
#  '家长': 12,
#  '允许': 2,
#  '访问': 2,
#  '范围': 2,
#  '安卓版': 1,
#  '即将': 54,
#  '耐心': 4,
#  '等待': 13,
#  '支持': 31,
#  '个人': 14,
#  '定制': 17,
#  '红包': 39,
#  '封面': 9,
#  '牌面': 1,
#  '拉满': 1,
#  '满足条件': 1,
#  '创作者': 2,
#  '价格': 4,
#  '为块': 1,
#  '一个个': 4,
#  '起订': 1,
#  '需': 5,
#  '满足': 5,
#  '以下': 15,
#  '两个': 13,
#  '条件': 1,
#  '开通': 3,
#  '完成': 15,
#  '认证': 2,
#  '发放': 5,
#  '粉丝': 59,
#  '领取': 20,
#  '发微信': 1,
#  '详细': 3,
#  '规则': 6,
#  '戳': 68,
#  '官网': 1,
#  '查看': 28,
#  '北京': 42,
#  '热血': 15,
#  '燃冰为': 1,
#  '冬奥': 5,
#  '助力': 23,
#  '一起': 203,
#  '关注': 188,
#  '冬奥会': 4,
#  '冬': 4,
#  '残奥会': 4,
#  '图标': 4,
#  '发布': 58,
#  '仪式': 6,
#  '年末': 5,
#  '狂欢': 11,
#  '早安': 16,
#  '时代': 38,
#  '少年': 76,
#  '团超话': 2,
#  '动力': 4,
#  '满满': 8,
#  '憧憬未来': 1,
#  '团是': 1,
#  '转评': 27,
#  '艾特': 3,
#  '一位': 38,
#  '互关': 3,
#  '好友': 20,
#  '抽送': 5,
#  '季卡': 3,
#  '冰雪': 4,
#  '江苏': 14,
#  '彩排': 8,
#  '演唱会': 17,
#  '少女': 29,
#  '蓄势待发': 4,
#  '时刻': 24,
#  '准备': 42,
#  '呈现': 12,
#  '完美': 16,
#  '舞台效果': 1,
#  '硬糖': 11,
#  '圆梦': 1,
#  '王一博': 16,
#  '加载': 2,
#  '矢志': 2,
#  '奋斗': 6,
#  '闪耀': 13,
#  '无限': 28,
#  '幸福': 32,
#  '光芒': 4,
#  '距离': 12,
#  '播出': 7,
#  '亚洲': 6,
#  '顶秀': 1,
#  '点亮': 5,
#  '鲸': 1,
#  '喜': 1,
#  '群星': 14,
#  '聚力': 2,
#  '之夜': 10,
#  '惊艳': 8,
#  '来袭': 31,
#  '进行': 65,
#  '创意': 13,
#  '舞美': 1,
#  '主题': 23,
#  '散发出': 1,
#  '光会': 1,
#  '即刻': 8,
#  '绽放': 4,
#  '盛典': 43,
#  '曝光': 21,
#  '微视': 5,
#  '小微': 3,
#  '日子': 11,
#  '一天': 28,
#  '美好': 15,
#  '两天': 5,
#  '见到': 7,
#  '团': 19,
#  '加盟': 3,
#  '团马嘉祺': 1,
#  '想要': 18,
#  '雷': 2,
#  '佳音': 4,
#  '高领': 3,
#  '毛衣': 4,
#  '链接': 167,
#  '接招': 2,
#  '前辈': 1,
#  '录制': 13,
#  '马嘉祺晒': 1,
#  '出和雷': 1,
#  '同框': 7,
#  '自拍': 1,
#  '问': 24,
#  '哥要': 1,
#  '弟弟': 6,
#  '太': 24,
#  '可爱': 23,
#  '辣': 2,
#  '看来': 8,
#  '真的': 23,
#  '喜欢': 56,
#  '在线': 19,
#  '蹲': 2,
#  '两位': 12,
#  '合作': 13,
#  '马嘉祺雷': 1,
#  '合照': 5,
#  '试问': 2,
#  '脸蛋': 3,
#  '不想': 10,
#  '杨': 16,
#  '超越': 3,
#  '段': 12,
#  '奥娟': 3,
#  '生日快乐': 28,
#  '听说': 19,
#  '岁': 53,
#  '天籁': 1,
#  '清澈': 1,
#  '嗓音': 5,
#  '娓娓道来': 2,
#  '明媚': 1,
#  '笑容': 3,
#  '治愈': 9,
#  '人心': 8,
#  '带来': 59,
#  '温暖': 30,
#  '无敌': 1,
#  '小可爱': 27,
#  '魅力': 12,
#  '百变': 7,
#  '可甜': 4,
#  '可飒': 1,
#  '一次': 42,
#  '惊喜': 44,
#  '愿': 10,
#  '追梦': 2,
#  '路上': 11,
#  '前程似锦': 1,
#  '繁华': 1,
#  '璀璨': 1,
#  '精彩': 39,
#  '清纯': 1,
#  '外表': 2,
#  '却是': 3,
#  '实力': 14,
#  '唱': 25,
#  '眼中': 2,
#  '甜美': 4,
#  '校服': 2,
#  '偶像': 7,
#  '天使': 1,
#  '吻': 2,
#  '表现力': 4,
#  '满分': 5,
#  '人生': 29,
#  '反转': 2,
#  '大片': 17,
#  '大娟': 1,
#  '爱': 55,
#  '高伟': 1,
#  '光华': 1,
#  '鼎奖': 1,
#  '古装': 4,
#  '题材': 6,
#  '最佳': 9,
#  '男主角': 1,
#  '第届': 10,
#  '华鼎奖': 6,
#  '恭喜': 62,
#  '高伟光': 5,
#  '三生': 3,
#  '三世': 2,
#  '枕上': 2,
#  '书': 7,
#  '获得': 78,
#  '中国': 102,
#  '电视剧': 26,
#  '男演员': 2,
#  '作品': 24,
#  '谭松': 1,
#  '韵华鼎奖': 1,
#  '女主角': 1,
#  '谭松韵': 4,
#  '锦衣': 2,
#  '之下': 5,
#  '女演员': 8,
#  '演员': 52,
#  '实至名归': 1,
#  '未来': 56,
#  '角色': 18,
#  '黄子': 7,
#  '韬': 6,
#  '出道': 7,
#  '周年': 46,
#  '祝': 18,
#  '快乐': 27,
#  '无论是': 1,
#  '歌手': 12,
#  '综艺': 49,
#  '很多': 29,
#  '希望': 42,
#  '真诚': 2,
#  '大大方方': 1,
#  '压箱底': 1,
#  '爱豆': 15,
#  '包亮': 1,
#  '喊': 3,
#  '来聊天': 1,
#  '终于': 24,
#  '团聚': 5,
#  '谢谢': 15,
#  '节日快乐': 2,
#  '吴刚': 8,
#  '长鹅在': 6,
#  '长鹅': 12,
#  '抽奖': 111,
#  '謝謝': 2,
#  '安排': 11,
#  '快点': 10,
#  '老师': 70,
#  '寄真': 1,
#  '长鹅长': 1,
#  '吳刚': 1,
#  '长鹅祝': 1,
#  '中秋': 12,
#  '大扎': 2,
#  '介四': 1,
#  '一款': 9,
#  '教大扎学': 1,
#  '普通话': 4,
#  '船': 2,
#  '游戏': 159,
#  '挤': 1,
#  '体验': 56,
#  '几番': 1,
#  '钟里': 1,
#  '造会': 1,
#  '爱象': 1,
#  '缩': 1,
#  '系弗兰人': 1,
#  '胡建人': 1,
#  '恁': 2,
#  '小镇': 1,
#  '学习': 18,
#  '治好': 1,
#  '分节': 1,
#  '款': 11,
#  '听懂': 1,
#  '欢迎': 28,
#  '下载': 20,
#  '捐出': 1,
#  '网页': 111,
#  '公司': 14,
#  '熊': 3,
#  '孩子': 46,
#  '哭': 9,
#  '防止': 3,
#  '假装': 1,
#  '拍照': 5,
#  '骗': 5,
#  '人脸识别': 3,
#  '未成年人': 8,
#  '出新招': 1,
#  '充值': 8,
#  '触发': 1,
#  '验证': 2,
#  '系统': 21,
#  '自动': 4,
#  '播报': 1,
#  '画面': 6,
#  '提示': 4,
#  '清晰': 7,
#  '提醒': 12,
#  '操作': 10,
#  '以后': 7,
#  '再也': 3,
#  '要脸': 1,
#  '不要': 27,
#  '随便': 1,
#  '人脸': 1,
#  '躲过': 2,
#  '健康': 25,
#  '大小': 2,
#  '朋友': 36,
#  '记住': 1,
#  '张靓颖': 5,
#  '邓紫棋': 4,
#  '小朋友': 6,
#  '账号': 12,
#  '水产': 1,
#  '姐妹': 8,
#  '欢乐': 9,
#  '扫': 3,
#  '海豚': 1,
#  '姐姐': 10,
#  '脸': 8,
#  '金鱼': 1,
#  '玩游戏': 4,
#  '强制': 1,
#  '下线': 4,
#  '三岁': 2,
#  '实锤': 1,
#  '官博': 2,
#  '正式': 90,
#  '提交': 2,
#  '代码': 5,
#  '整整': 1,
#  '凌晨': 5,
#  '广州': 19,
#  '一群': 5,
#  '年轻人': 10,
#  '小黑': 2,
#  '屋里': 3,
#  '敲下': 1,
#  '一行行': 1,
#  '沟通': 7,
#  '方式': 22,
#  '变': 7,
#  '后台': 7,
#  '第一天': 4,
#  '年前': 4,
#  '今晚': 49,
#  '干嘛': 1,
#  '送到': 3,
#  '广寒宫': 1,
#  '图片': 32,
#  '良言': 3,
#  '写意': 4,
#  '十年': 20,
#  '励行': 2,
#  '一场': 31,
#  '浪漫': 8,
#  '邂逅': 4,
#  '祝出': 2,
#  '道': 14,
#  '十周年': 18,
#  '携手': 22,
#  '前行': 9,
#  '罗云熙': 9,
#  '有翡': 14,
#  '沉迷': 2,
#  '不能自拔': 1,
#  '发挥': 3,
#  '想法': 7,
#  '即日起': 11,
#  '登录': 14,
#  '参与': 56,
#  '征稿': 1,
#  '接力': 3,
#  '活动': 106,
#  '熹微': 1,
#  '翻唱': 2,
#  '大赛': 20,
#  '翡': 3,
#  '剪辑': 2,
#  '双剑齐': 1,
#  '发总有': 1,
#  '体现': 3,
#  '过人之处': 1,
#  '机会': 37,
#  '千元': 2,
#  '现金': 10,
#  '周边': 19,
#  '大礼包': 16,
#  '丰厚': 5,
#  '奖品': 9,
#  '官方': 49,
#  '赵丽颖': 25,
#  '形容': 5,
#  '周翡': 20,
#  '肉盾': 6,
#  '入戏': 10,
#  '采访': 6,
#  '公开': 13,
#  '说起': 4,
#  '一直': 30,
#  '战斗': 1,
#  '挥刀': 3,
#  '潇洒': 5,
#  '帅气': 3,
#  '满面笑容': 1,
#  '看出': 1,
#  '热爱': 34,
#  '表演': 16,
#  '越走越远': 1,
#  '人情世故': 3,
#  '矫情': 6,
#  '风暴': 7,
#  '时间': 32,
#  '玫瑰': 3,
#  '千呼万唤': 5,
#  '霸': 2,
#  '总': 9,
#  '咯': 12,
#  '高': 5,
#  '投': 5,
#  '蛋糕': 1,
#  '尝': 1,
#  '一口': 3,
#  '转发': 176,
#  '此条': 5,
#  '三位': 12,
#  '说出': 18,
#  '生日': 20,
#  '祝福': 21,
#  '签名': 23,
#  '胡': 4,
#  '自夸': 1,
#  '切得': 1,
#  '一手': 3,
#  '百岁之好': 1,
#  '一言为定': 1,
#  '超前': 1,
#  '点播': 1,
#  '神马': 1,
#  '没': 24,
#  '涵': 1,
#  '特辑': 5,
#  '少说多做': 1,
#  '见': 31,
#  '不平': 1,
#  '相助': 1,
#  '遇': 1,
#  '不忿': 1,
#  '敢言': 1,
#  '正理': 1,
#  '坚守': 4,
#  '凡此种种': 1,
#  '皆': 7,
#  '侠者': 1,
#  '周': 20,
#  '翡必': 1,
#  '不负': 6,
#  '手中': 3,
#  '之刀': 1,
#  '快意': 3,
#  '江湖': 10,
#  '灭': 2,
#  '心底': 1,
#  '自由': 6,
#  '驰骋': 1,
#  '正义': 14,
#  '执刀': 2,
#  '从小': 1,
#  '情侣': 1,
#  '全世界': 1,
#  '路过': 3,
#  '绝不': 5,
#  '错过': 19,
#  '孙坚': 1,
#  '空降': 13,
#  '明星': 34,
#  '超有': 2,
#  '单身贵族': 1,
#  '宝': 10,
#  '聊聊吧': 1,
#  '预约': 27,
#  '余年': 6,
#  '有幸': 4,
#  '评论': 112,
#  '抽': 33,
#  '庆送': 1,
#  '你好': 5,
#  '神枪手': 1,
#  '倾听': 8,
#  '内心': 13,
#  '笃定': 1,
#  '见证': 22,
#  '成长': 31,
#  '蜕变': 5,
#  '书写': 2,
#  '祝海雅': 1,
#  '大学': 5,
#  '射击队': 1,
#  '队长': 1,
#  '沈': 4,
#  '清源': 1,
#  '早日': 3,
#  '相见': 3,
#  '更凉': 1,
#  '窝': 1,
#  '家里': 6,
#  '看看': 28,
#  '琅': 4,
#  '琊': 1,
#  '榜': 15,
#  '送出': 8,
#  '体验版': 3,
#  '已于': 1,
#  '商店': 9,
#  '免费': 25,
#  '扫码': 10,
#  '电脑': 6,
#  '端及': 2,
#  '移动': 4,
#  '端': 5,
#  '共享': 8,
#  '信息': 19,
#  '无需': 6,
#  '重复': 4,
#  '超级': 45,
#  '影视': 6,
#  '最高': 5,
#  '清晰度': 1,
#  '引进': 6,
#  '庆典': 11,
#  '一图': 6,
#  '国行': 6,
#  '一周年': 2,
#  '运动': 10,
#  '工具': 20,
#  '跳绳': 1,
#  '挑战': 23,
#  '冒险游戏': 1,
#  '健身': 8,
#  '环': 2,
#  '大冒险': 3,
#  '探索': 13,
#  '广袤': 1,
#  '世界': 64,
#  '马力': 2,
#  '欧': 2,
#  '奥德赛': 1,
#  '解谜': 3,
#  '微缩': 1,
#  '光影': 3,
#  '彩虹': 4,
#  '坠入': 2,
#  '展示': 7,
#  '过去': 9,
#  '近': 3,
#  '一年': 41,
#  '天后': 2,
#  '折扣': 7,
#  '开发': 9,
#  '体感': 1,
#  '音乐': 91,
#  '舞力': 4,
#  '全开': 4,
#  '旗舰店': 1,
#  '预售': 7,
#  '发售': 4,
#  '本体': 1,
#  '包含': 7,
#  '首': 3,
#  '中外': 1,
#  '流行歌曲': 1,
#  '订阅': 1,
#  '服务': 10,
#  '解锁': 22,
#  '多曲': 1,
#  '库': 2,
#  '内容': 21,
#  '采用': 9,
#  '双': 26,
#  '定价': 2,
#  '网球': 1,
#  '上市': 7,
#  '工作': 24,
#  '开展': 2,
#  '后续': 11,
#  '进展': 1,
#  '将会': 11,
#  '渠道': 2,
#  '告知': 2,
#  '感谢': 61,
#  '对国行': 1,
#  '关心': 3,
#  '本次': 31,
#  '以下内容': 1,
#  '节奏': 6,
#  '跟随': 5,
#  '合适': 8,
#  '时机': 2,
#  '推压': 1,
#  '旋转': 1,
#  '冲击': 4,
#  ...}
